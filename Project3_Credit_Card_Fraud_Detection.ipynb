# %% [markdown]
# <a href="https://colab.research.google.com/github/AyushSinghRajput1366/Machine-learning-Project/blob/main/Project3_Credit_Card_Fraud_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import dependecies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# loading the dataset to a  pandas dataframe
credit_card_data= pd.read_csv('/content/creditcard (1).csv')

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 67429  52531 -0.668025  0.539737  0.161731 -1.071380  1.529141  3.819435
# 67430  52532 -0.679169  1.237672  1.602476 -0.007797 -0.228123 -1.095514
# 67431  52532 -0.102663  0.890146  1.178701 -0.062896  0.289073 -0.377077
# 67432  52532  0.797464 -0.947293  1.045822  0.263474 -1.194980  0.348919
# 67433  52534  1.210560  0.291028  0.273319  0.646091 -0.199608 -0.606096
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 67429 -0.685869  1.486179 -0.293208  ...  0.214492  0.282335  0.070720
# 67430  0.734340 -0.106748 -0.298766  ... -0.233214 -0.517932  0.020122
# 67431  0.753827  0.035692 -0.936965  ... -0.292659 -0.897627  0.275655
# 67432 -0.594826  0.268371  0.870239  ... -0.039739 -0.211713 -0.023972
# 67433  0.000425 -0.056976  0.051479  ...       NaN       NaN       NaN
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
credit_card_data.shape
# Out:
# (67434, 31)

# %%
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67434 entries, 0 to 67433
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    67434 non-null  int64
#  1   V1      67434 non-null  float64
#  2   V2      67434 non-null  float64
#  3   V3      67434 non-null  float64
#  4   V4      67434 non-null  float64
#  5   V5      67434 non-null  float64
#  6   V6      67434 non-null  float64
#  7   V7      67434 non-null  float64
#  8   V8      67434 non-null  float64
#  9   V9      67434 non-null  float64
#  10  V10     67434 non-null  float64
#  11  V11     67434 non-null  float64
#  12  V12     67434 non-null  float64
#  13  V13     67434 non-null  float64
#  14  V14     67434 non-null  float64
#  15  V15     67434 non-null  float64
#  16  V16     67434 non-null  float64
#  17  V17     67434 non-null  float64
#  18  V18     67434 non-null  float64
#  19  V19     67434 non-null  float64
# ...

# %%
# checking the missing values in each column
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
# distribution of legit and fraudulent data

credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    67264
# 1.0      169
# Name: count, dtype: int64

# %% [markdown]
# this is highly Imblanced data

# %% [markdown]
# 0 --> legit transaction
#
# 1 --> fraudulent transaction

# %%
# seprating the legit and fraudulent data
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print('Legit data =',legit.shape)
print('fraud Data =',fraud.shape)
print("Total Data =",credit_card_data.shape)
# Out:
# Legit data = (67264, 31)
# fraud Data = (169, 31)
# Total Data = (67434, 31)

# %% [markdown]
# Under Sampling

# %% [markdown]
# build a sample data set containing distribution of legit and fraudulent reansaction

# %% [markdown]
# Number of Fraudulent dataset --> 169

# %%
legit_sample = legit.sample(n=169)

# %%
print(legit_sample.shape)
# Out:
# (169, 31)

# %% [markdown]
# Concatenate the two dataFrames

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 54171  46317  1.295901  0.325427  0.329835  0.492263 -0.128351 -0.678656
# 43086  41367  1.101972  0.000156  0.047565  1.255159 -0.205436 -0.443217
# 49596  44129  1.281132 -0.024727  0.238407 -0.260097 -0.413370 -0.645515
# 18903  29855  1.225320  0.240740  0.643588  0.702698 -0.644319 -1.177505
# 45411  42330  1.175803  0.329301  0.503150  0.767234 -0.432818 -0.904234
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 54171  0.134920 -0.243576 -0.106887  ... -0.275952 -0.735622  0.059986
# 43086  0.180445 -0.014483  0.379110  ...  0.003436  0.009948 -0.142936
# 49596 -0.142572 -0.059950  0.035178  ... -0.082132 -0.257884 -0.004249
# 18903  0.078476 -0.229300  0.018922  ... -0.231970 -0.685859  0.171202
# 45411  0.028788 -0.106361 -0.026555  ... -0.223601 -0.607434  0.223062
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset.tail()
# Out:
#         Time         V1        V2         V3        V4        V5        V6  \
# 63421  50706  -8.461845  6.866198 -11.838269  4.194211 -6.923097 -3.221147
# 63634  50808  -9.169790  7.092197 -12.354037  4.243069 -7.176438 -3.386618
# 64329  51112  -9.848776  7.365546 -12.898538  4.273323 -7.611991 -3.427045
# 64411  51135 -10.527304  7.639745 -13.443115  4.303403 -8.048210 -3.466997
# 64460  51155 -11.205461  7.914633 -13.987752  4.333341 -8.484970 -3.506561
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 63421 -7.553497  6.015618 -2.466143  ...  0.918244 -0.715366  0.210747
# 63634 -8.058012  6.442909 -2.412987  ...  0.926157 -0.817706 -0.150434
# 64329 -8.350808  6.863604 -2.387567  ...  0.931958 -0.874467 -0.192639
# 64411 -8.643193  7.284105 -2.362097  ...  0.937416 -0.931178 -0.235697
# 64460 -8.935243  7.704449 -2.336584  ...  0.942593 -0.987848 -0.279446
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    169
# 1.0    169
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    33339.437870 -0.222215 -0.070246  0.576080  0.205497 -0.449159
# 1.0    29493.242604 -7.106029  5.115846 -9.566072  5.470948 -5.263861
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.010112 -0.059186  0.085625 -0.011298  ...  0.126945 -0.036763
# 1.0   -2.172211 -7.412550  3.501007 -3.298551  ...  0.431494  0.850670
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.115146 -0.088003 -0.039934  0.167969 -0.088086  0.026684  0.002188
# 1.0   -0.212903 -0.255225 -0.075295  0.245601  0.107931  0.576249  0.041284
#
#           Amount
# Class
# 0.0    124.80213
# 1.0     94.89568
#
# [2 rows x 30 columns]

# %%
#Statistical measure of th data
legit.Amount.describe()
# Out:
# count    67264.000000
# mean        96.632489
# std        270.008302
# min          0.000000
# 25%          7.680000
# 50%         26.380000
# 75%         88.360000
# max      19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     169.000000
# mean       94.895680
# std       220.959331
# min         0.000000
# 25%         1.000000
# 50%         7.610000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
#Compare the values for both transaction
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    33987.964275 -0.224397 -0.031225  0.709220  0.156146 -0.256028
# 1.0    29493.242604 -7.106029  5.115846 -9.566072  5.470948 -5.263861
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.107483 -0.096094  0.048974  0.038459  ...  0.046365 -0.030766
# 1.0   -2.172211 -7.412550  3.501007 -3.298551  ...  0.431494  0.850670
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.106221 -0.038280  0.005830  0.136332  0.020505  0.001370  0.003425
# 1.0   -0.212903 -0.255225 -0.075295  0.245601  0.107931  0.576249  0.041284
#
#           Amount
# Class
# 0.0    96.632489
# 1.0    94.895680
#
# [2 rows x 30 columns]

# %% [markdown]
# Spliting the data into Feature and target

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y= new_dataset['Class']

# %%
print(X)
# Out:
#         Time         V1        V2         V3        V4        V5        V6  \
# 54171  46317   1.295901  0.325427   0.329835  0.492263 -0.128351 -0.678656
# 43086  41367   1.101972  0.000156   0.047565  1.255159 -0.205436 -0.443217
# 49596  44129   1.281132 -0.024727   0.238407 -0.260097 -0.413370 -0.645515
# 18903  29855   1.225320  0.240740   0.643588  0.702698 -0.644319 -1.177505
# 45411  42330   1.175803  0.329301   0.503150  0.767234 -0.432818 -0.904234
# ...      ...        ...       ...        ...       ...       ...       ...
# 63421  50706  -8.461845  6.866198 -11.838269  4.194211 -6.923097 -3.221147
# 63634  50808  -9.169790  7.092197 -12.354037  4.243069 -7.176438 -3.386618
# 64329  51112  -9.848776  7.365546 -12.898538  4.273323 -7.611991 -3.427045
# 64411  51135 -10.527304  7.639745 -13.443115  4.303403 -8.048210 -3.466997
# 64460  51155 -11.205461  7.914633 -13.987752  4.333341 -8.484970 -3.506561
#
# ...

# %%
print(Y)
# Out:
# 54171    0.0
# 43086    0.0
# 49596    0.0
# 18903    0.0
# 45411    0.0
#         ...
# 63421    1.0
# 63634    1.0
# 64329    1.0
# 64411    1.0
# 64460    1.0
# Name: Class, Length: 338, dtype: float64

# %% [markdown]
# Spliting the data into traing and test data

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (338, 30) (270, 30) (68, 30)

# %% [markdown]
# Model train --> logistic regeration

# %%
Model = LogisticRegression()

# %% [markdown]
# training the model regression with training

# %%
Model.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Model Evaluation
#
# Accuracy Score

# %%
# accuracy score on the training data
X_train_prediction = Model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction,Y_train)

# %%
print("Accuracy on training data",training_data_accuracy)
# Out:
# Accuracy on training data 0.9518518518518518

# %%
from re import M
# accuracy score on the training data
X_test_prediction = Model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print("Accuracy on the test data",test_data_accuracy)
# Out:
# Accuracy on the test data 0.9411764705882353
